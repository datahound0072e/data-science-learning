# %%
import sys
import numpy as np
import pandas as pd
import sklearn

print("Python:", sys.executable)
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Scikit-learn:", sklearn.__version__)
# Out:
# Python: /home/orfs/data-science/.venv/bin/python
# NumPy: 2.2.6
# Pandas: 2.3.3
# Scikit-learn: 1.7.2
